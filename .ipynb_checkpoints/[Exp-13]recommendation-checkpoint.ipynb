# %% [markdown]
# # explororation 13 : 아이유팬이 좋아할 만한 다른 아티스트 찾기

# %% [markdown]
# **루브릭 1. CSR matrix가 정상적으로 만들어졌다.**
# 사용자와 아이템 개수를 바탕으로 정확한 사이즈로 만들었다.
#
# -> 잘 진행되었습니다.
#
# **루브릭 2. MF 모델이 정상적으로 훈련되어 그럴듯한 추천이 이루어졌다.**
# 사용자와 아이템 벡터 내적수치가 의미있게 형성되었다.
#
# -> 잘 진행되었습니다.
#
# **루브릭 3. 비슷한 영화 찾기와 유저에게 추천하기의 과정이 정상적으로 진행되었다.**
# MF모델이 예측한 유저 선호도 및 아이템간 유사도, 기여도를 측정하고 의미를 분석해보았다.
#
# -> 잘 진행되었습니다.

# %% [markdown]
# ***

# %% [markdown]
# # 1. 이론에 대한 이해

# %% [markdown]
# implicit은 '암시적'이라는 뜻이다. explicit(명시적)이라는 단어의 반댓말이다.
# 추천시스템에 사용하는 데이터가 좋아요나 별점처럼 선호도가 명시적으로 드러나는 데이터면 좋겠지만, 그런 경우는 잘 없다.
# 특히 우리는 암시적인 데이터에 대해서, 선호도를 계산하는 작업을 해보려 한다.
#
# 노드 13-7에서 `implicit` 패키지에 대해 설명하고 있다. 이 패키지는, implicit dataset을 사용하는 다양한 모델을 빠르게 학습하도록 한다.
# 여기에서 우리는 `als`(AlternatingLeastSquares) 모델을 사용하게 된다.
# 이것은, 주어진 평가행렬 R(rating matrix)를 두 개의 행렬 P, Q의 곱으로 나타내는 matrix factorization(decomposition)을 할 때
# P와 Q를 동시에 학습하지 않고, P를 학습했다가 Q를 학습했다가 하며 교차적으로(alternating) 학습한다는 의미이다.
# 이 matrix factorization에 대하여 아래에 마크다운으로 조금 더 적어보자.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 위와 같은 rating matrix $R$이 있다고 하자.
# $R$은 $m\times n$ 행렬인데 이것을 $m\times k$ 행렬인 $P$와 $k\times n$ 행렬 $Q$의 곱으로 표현하게 된다.
# 이때, $m$은 유저 수(the number of users)가 될 것이고, $n$은 아이템 수(the number of items, i.e., the number of artist)가 될 것이다.
# 이때, $m$과 $n$보다 조금 더 작은 $k$라는 자연수를 생각하고, $m\times n$ 행렬의 정보를 $k$차원에 embedding 시키는 것으로 생각된다.
# 이때, $k$를 특성의 개수(the number of features)라고 부르고 있다.
#
# 즉, $R$은 $mn$개의 entry로 되어 있는데, 이것을 $mk+nk=(m+n)k$개의 entry로 다시 표현하는 것이다. $k$가 $m$과 $n$에 비해서 작다면, 이것은 원칙적으로 불가능하다.
# 기존($mn$)보다 더 적은($(m+n)k$) 숫자로 기존의 데이터를 표현해야 한다.
#
# rank의 관점에서 생각해볼 수도 있다.
# 선형대수에서 나오는 기본적인 사실이지만, $m\times 1$ 행렬과 $1\times n$ 행렬을 행렬곱하면, 그 결과로 생기는 $m\times n$ 행렬은 rank 1 행렬이다.
# 아무리 $m$, $n$이 크다고 하더라도, 별로 많은 의미를 담고 있지 않은 행렬이라는 뜻이다.
# 모든 행들이 linearly dependent하고 모든 열들도 linearly dependent하다.
# 이런 행렬에서 1만 $k$로 바뀐 행렬이 $P$와 $Q$이다.
# 따라서 행렬 $PQ$는 rank k일 것이라고 추측할 수 있을 것 같다.
# (정확하게는, 조금 더 생각해봐야 할 것이다.)
#
# 또한가지 점은 $R=PQ$가 아니라, $R\approx PQ$라는 것이다.
# 그래서 일반적인 의미에서의 decomposition이나 factorization이 아니다.
# LU decomposition이나 diagonalization에서처럼 정확히 같은 행렬로 분해하는 것이 아니라 비슷한 행렬로 근사하는 것이다.
# 최근에 공부하게 되었던 Rayleigh quotient처럼, 아니면 (아마도) PCA에서 등장하는 pseudo-inverse처럼 근사(approximation)에 사용하는 것이다.
#
# 어떤 norm의 관점에서 근사한 것인지, 또 어떤 원리에 의해서 근사되는 지 하는 것은 이번 노드에 구체적으로 명시되어 있지는 않다.
# 11월 중에 LG 대회를 준비하면서, 이것들을 다시 공부해보는 것도 재밌을 것 같다.

# %% [markdown]
# # 2. Movielens 영화 추천 실습

# %% [markdown]
# ## 2.1. 데이터 준비와 전처리

# %%
import numpy as np
import pandas as pd
import scipy

import implicit
import os
from scipy.sparse import csr_matrix
from implicit.als import AlternatingLeastSquares

# %%
# orginal_data_size라고 되어 있는 객체명을 original_data_size라고 바꿨다. 아무리 봐도 오타이다.

rating_file_path=os.getenv('HOME') + '/aiffel/recommendata_iu/data/ml-1m/ratings.dat'
ratings_cols = ['user_id', 'movie_id', 'ratings', 'timestamp']
ratings = pd.read_csv(rating_file_path, sep='::', names=ratings_cols, engine='python', encoding = "ISO-8859-1")
original_data_size = len(ratings)
ratings.head()
# Out:
#    user_id  movie_id  ratings  timestamp
# 0        1      1193        5  978300760
# 1        1       661        3  978302109
# 2        1       914        3  978301968
# 3        1      3408        4  978300275
# 4        1      2355        5  978824291

# %%
# 데이터셋은 100만개의 sample들로 구성되어 있다.
print(ratings.shape)
print(original_data_size)
# Out:
# (1000209, 4)
# 1000209

# %%
# column들 중 의미있는 것들은 user_id, movie_id, ratings이다. timestamp는 안쓰니까 없애버리자.
ratings.drop(['timestamp'],axis=1, inplace=True)
ratings
# Out:
#          user_id  movie_id  ratings
# 0              1      1193        5
# 1              1       661        3
# 2              1       914        3
# 3              1      3408        4
# 4              1      2355        5
# ...          ...       ...      ...
# 1000204     6040      1091        1
# 1000205     6040      1094        5
# 1000206     6040       562        5
# 1000207     6040      1096        4
# 1000208     6040      1097        4
#
# [1000209 rows x 3 columns]

# %%
# 조금 더 데이터셋을 뜯어보자.
print(ratings['user_id'].max())
print(ratings['movie_id'].max())
print(ratings['ratings'].max())
print(ratings['user_id'].unique())
print(ratings['movie_id'].unique())
print(ratings['ratings'].unique())
print(ratings['user_id'].nunique())
print(ratings['movie_id'].nunique())
print(ratings['ratings'].nunique())
# Out:
# 6040
# 3952
# 5
# [   1    2    3 ... 6038 6039 6040]
# [1193  661  914 ... 2845 3607 2909]
# [5 3 4 2 1]
# 6040
# 3706
# 5

# %%
# user_id는 최댓값도 6040이고 nunique값도 6040이다. 다시 말해, 1부터 6040까지의 값들이 죽 나열되어 있음을 알 수 있다.
# movie_id는 최댓값은 3952이지만 nunique값은 3706이다. 다시 말해, index가 붙여진 영화들 중 ratings에 한 번도 나오지 않는 영화가 존재한다.
# 심심하니깐 조금 더 알아봐보자.

# %%
# 영화별 상영횟수 (내림차순)
# movie_id로 그룹화한 다음 ratings의 개수를 센다. 여기서 ratings 대신 어떤 열이 들어가도 상관없다.
movie_count = ratings.groupby('movie_id')['ratings'].count()
movie_count.sort_values(ascending=False).head(10)
# Out:
# movie_id
# 2858    3428
# 260     2991
# 1196    2990
# 1210    2883
# 480     2672
# 2028    2653
# 589     2649
# 2571    2590
# 1270    2583
# 593     2578
# Name: ratings, dtype: int64

# %%
# 유저별 관람횟수 (내림차순)
# user_id로 그룹화한 다음 ratings의 개수를 센다. 이번에도 ratings 열이 것은 중요하지 않다.
user_count = ratings.groupby('user_id')['ratings'].count()
user_count.sort_values(ascending=False).head(10)
# Out:
# user_id
# 4169    2314
# 1680    1850
# 4277    1743
# 1941    1595
# 1181    1521
# 889     1518
# 3618    1344
# 2063    1323
# 1150    1302
# 1015    1286
# Name: ratings, dtype: int64

# %%
# 유저별 관람횟수 (통계)
user_count.describe()
# Out:
# count    6040.000000
# mean      165.597517
# std       192.747029
# min        20.000000
# 25%        44.000000
# 50%        96.000000
# 75%       208.000000
# max      2314.000000
# Name: ratings, dtype: float64

# %%
# 유저별 별점 중앙값에 대한 통계
# user_id로 그룹화한 다음 ratings의 중앙값을 계산한다. 이번에도 ratings 열인 것은 중요하지 않다.
user_median = ratings.groupby('user_id')['ratings'].median()
user_median.describe()
# Out:
# count    6040.000000
# mean        3.840811
# std         0.577449
# min         1.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: ratings, dtype: float64

# %%
# 3점 이상만 남깁니다.
ratings = ratings[ratings['ratings']>=3]
filtered_data_size = len(ratings)

print(f'original_data_size: {original_data_size}, filtered_data_size: {filtered_data_size}')
print(f'Ratio of Remaining Data is {filtered_data_size / original_data_size:.2%}')
# Out:
# original_data_size: 1000209, filtered_data_size: 836478
# Ratio of Remaining Data is 83.63%

# %%
# 3점 이상의 별점만 남겨졌음을 확인할 수 있다.
ratings
# Out:
#          user_id  movie_id  ratings
# 0              1      1193        5
# 1              1       661        3
# 2              1       914        3
# 3              1      3408        4
# 4              1      2355        5
# ...          ...       ...      ...
# 1000203     6040      1090        3
# 1000205     6040      1094        5
# 1000206     6040       562        5
# 1000207     6040      1096        4
# 1000208     6040      1097        4
#
# [836478 rows x 3 columns]

# %%
# ratings 컬럼의 이름을 counts로 바꿉니다.
# warning 왜?
# ratings 컬럼의 이름을 counts로 바꿉니다.
ratings.rename(columns={'ratings':'counts'}, inplace=True)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
ratings
# Out:
#          user_id  movie_id  counts
# 0              1      1193       5
# 1              1       661       3
# 2              1       914       3
# 3              1      3408       4
# 4              1      2355       5
# ...          ...       ...     ...
# 1000203     6040      1090       3
# 1000205     6040      1094       5
# 1000206     6040       562       5
# 1000207     6040      1096       4
# 1000208     6040      1097       4
#
# [836478 rows x 3 columns]

# %%
# 별로 의미없는 셀인 것 같아 주석처리 하였다.
# ratings['counts']

# %%
# 영화 제목을 보기 위해 메타 데이터를 읽어옵니다.
movie_file_path=os.getenv('HOME') + '/aiffel/recommendata_iu/data/ml-1m/movies.dat'
cols = ['movie_id', 'title', 'genre'] 
movies = pd.read_csv(movie_file_path, sep='::', names=cols, engine='python', encoding='ISO-8859-1')
movies.head()
# Out:
#    movie_id                               title                         genre
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
print(ratings['user_id'].max())
print(ratings['movie_id'].max())
print(ratings['user_id'].nunique())
print(ratings['movie_id'].nunique())
# Out:
# 6040
# 3952
# 6039
# 3628

# %%
# movie_id의 최댓값은 ratings와 movies에서 같다. (말이 된다.)
# movie_id의 (서로 다른 것들의 개수는) ratings에서가 movies에서보다 더 적다. 하지만 크게 문제될 건 없을 것이다.
# title은 하나도 중복되는 것이 없다.
# genre는 당연히 중복되는데, 서로 다른 것들의 개수가 무려 301개나 된다. 장르를 하나만 적는 게 아니라 여러 개 적으니까 많아진 것 같다.
print(movies.shape)
print(movies['movie_id'].max())
print(movies['movie_id'].nunique())
print(movies['title'].nunique())
print(movies['genre'].nunique())
# Out:
# (3883, 3)
# 3952
# 3883
# 3883
# 301

# %%
# ind_to_movie를 만들어두자.
ind_to_movie = dict(zip(movies['movie_id'],movies['title']))
ind_to_movie[1]
# Out:
# 'Toy Story (1995)'

# %%
# ind_to_genre도 만들어두자.
ind_to_genre = dict(zip(movies['movie_id'],movies['genre']))
ind_to_genre[1]
# Out:
# "Animation|Children's|Comedy"

# %%
ratings
# Out:
#          user_id  movie_id  counts
# 0              1      1193       5
# 1              1       661       3
# 2              1       914       3
# 3              1      3408       4
# 4              1      2355       5
# ...          ...       ...     ...
# 1000203     6040      1090       3
# 1000205     6040      1094       5
# 1000206     6040       562       5
# 1000207     6040      1096       4
# 1000208     6040      1097       4
#
# [836478 rows x 3 columns]

# %%
ratings['title'] = ratings['movie_id'].apply(lambda x:ind_to_movie[x])
# Out:
# /tmp/ipykernel_272/3891107223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings['title'] = ratings['movie_id'].apply(lambda x:ind_to_movie[x])

# %%
ratings['genre'] = ratings['movie_id'].apply(lambda x:ind_to_genre[x])
# Out:
# /tmp/ipykernel_272/1052735154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings['genre'] = ratings['movie_id'].apply(lambda x:ind_to_genre[x])

# %%
ratings
# Out:
#          user_id  movie_id  counts                                   title  \
# 0              1      1193       5  One Flew Over the Cuckoo's Nest (1975)
# 1              1       661       3        James and the Giant Peach (1996)
# 2              1       914       3                     My Fair Lady (1964)
# 3              1      3408       4                  Erin Brockovich (2000)
# 4              1      2355       5                    Bug's Life, A (1998)
# ...          ...       ...     ...                                     ...
# 1000203     6040      1090       3                          Platoon (1986)
# 1000205     6040      1094       5                 Crying Game, The (1992)
# 1000206     6040       562       5         Welcome to the Dollhouse (1995)
# 1000207     6040      1096       4                  Sophie's Choice (1982)
# 1000208     6040      1097       4       E.T. the Extra-Terrestrial (1982)
#
#                                    genre
# ...

# %% [markdown]
# ## 2.2. 분석해봅시다

# %%
# 아까 했던 것들 다시 불러오자.

# %%
# ratings에 있는 유니크한 영화 개수
ratings['movie_id'].nunique()
# Out:
# 3628

# %%
# ratings에 있는 유니크한 사용자 수
ratings['user_id'].nunique()
# Out:
# 6039

# %%
# 가장 인기 있는 영화 30개(인기순)
movie_count = ratings.groupby('title')['counts'].count()
movie_count.sort_values(ascending=False).head(30)
# Out:
# title
# American Beauty (1999)                                   3211
# Star Wars: Episode IV - A New Hope (1977)                2910
# Star Wars: Episode V - The Empire Strikes Back (1980)    2885
# Star Wars: Episode VI - Return of the Jedi (1983)        2716
# Saving Private Ryan (1998)                               2561
# Terminator 2: Judgment Day (1991)                        2509
# Silence of the Lambs, The (1991)                         2498
# Raiders of the Lost Ark (1981)                           2473
# Back to the Future (1985)                                2460
# Matrix, The (1999)                                       2434
# Jurassic Park (1993)                                     2413
# Sixth Sense, The (1999)                                  2385
# Fargo (1996)                                             2371
# Braveheart (1995)                                        2314
# Men in Black (1997)                                      2297
# ...

# %%
# ratings.drop(['title','genre'],axis=1, inplace=True)
# ratings

# %% [markdown]
# ## 2.3. 내가 선호하는 영화를 5가지 골라서 ratings에 추가해 줍시다.

# %%
ratings
# Out:
#          user_id  movie_id  counts                                   title  \
# 0              1      1193       5  One Flew Over the Cuckoo's Nest (1975)
# 1              1       661       3        James and the Giant Peach (1996)
# 2              1       914       3                     My Fair Lady (1964)
# 3              1      3408       4                  Erin Brockovich (2000)
# 4              1      2355       5                    Bug's Life, A (1998)
# ...          ...       ...     ...                                     ...
# 1000203     6040      1090       3                          Platoon (1986)
# 1000205     6040      1094       5                 Crying Game, The (1992)
# 1000206     6040       562       5         Welcome to the Dollhouse (1995)
# 1000207     6040      1096       4                  Sophie's Choice (1982)
# 1000208     6040      1097       4       E.T. the Extra-Terrestrial (1982)
#
#                                    genre
# ...

# %%
ratings.to_csv('ratings.csv')

# %%
# ratings[ratings['title']=='Terminator, The (1984)']
ratings[ratings['title']=='Tarzan (1999)']
# Out:
#         user_id  movie_id  counts          title                 genre
# 16            1      2687       3  Tarzan (1999)  Animation|Children's
# 2368         19      2687       4  Tarzan (1999)  Animation|Children's
# 5159         36      2687       5  Tarzan (1999)  Animation|Children's
# 6926         48      2687       3  Tarzan (1999)  Animation|Children's
# 7170         49      2687       3  Tarzan (1999)  Animation|Children's
# ...         ...       ...     ...            ...                   ...
# 996812     6017      2687       5  Tarzan (1999)  Animation|Children's
# 997397     6023      2687       5  Tarzan (1999)  Animation|Children's
# 998001     6029      2687       4  Tarzan (1999)  Animation|Children's
# 998086     6030      2687       4  Tarzan (1999)  Animation|Children's
# 999268     6036      2687       5  Tarzan (1999)  Animation|Children's
#
# [389 rows x 5 columns]

# %% [markdown]
# 내가 선호하는 영화가 다음과 같다고 가정하자.
# 실험을 위해, 비슷해보이는 영화 장르로 설정했다.
#
# 아래 영화들은 주로 아이들을 위한 만화영화들이다.
# 하지만, 너무 똑같은 장르의 영화를 설정하기보다는, Animation, Children's 라는 두 개 장르를 공유하면서, 다른 장르들도 가지도록 하였다.
#
# |movie_id|title|genre|
# |:-:|:-:|:-:|
# |2687|Tarzan (1999)|Animation\|Children's|
# |48|Pocahontas (1995)|Animation\|Children's\|Musical\|Romance|
# |1907|Mulan (1998)|Animation\|Children's|
# |1566|Hercules (1997)|Adventure\|Animation\|Children's\|Comedy\|Musical|
# |1|Toy Story (1995)|Animation\|Children's\|Comedy|

# %%
my_favorite = ['Tarzan (1999)', 'Pocahontas (1995)', 'Mulan (1998)', 'Hercules (1997)', 'Toy Story (1995)']
corresponding_genre = ["Animation|Children's","Animation|Children's|Musical|Romance","Animation|Children's",
                       "Adventure|Animation|Children's|Comedy|Musical","Animation|Children's|Comedy"]

# %%
my_watchlist = pd.DataFrame({'user_id':['SJ']*5,'movie_id':[2687, 48, 1907, 1566, 1],'counts':[5]*5,
                            'title':my_favorite ,'genre':corresponding_genre})

# %%
if not ratings.isin({'user_id':['SJ']})['user_id'].any():  # user_id에 'zimin'이라는 데이터가 없다면
    ratings = ratings.append(my_watchlist)                           # 위에 임의로 만든 my_favorite 데이터를 추가해 줍니다. 
ratings.tail(10)
# Out:
#         user_id  movie_id  counts                              title  \
# 1000203    6040      1090       3                     Platoon (1986)
# 1000205    6040      1094       5            Crying Game, The (1992)
# 1000206    6040       562       5    Welcome to the Dollhouse (1995)
# 1000207    6040      1096       4             Sophie's Choice (1982)
# 1000208    6040      1097       4  E.T. the Extra-Terrestrial (1982)
# 0            SJ      2687       5                      Tarzan (1999)
# 1            SJ        48       5                  Pocahontas (1995)
# 2            SJ      1907       5                       Mulan (1998)
# 3            SJ      1566       5                    Hercules (1997)
# 4            SJ         1       5                   Toy Story (1995)
#
#                                                  genre
# 1000203                                      Drama|War
# 1000205                              Drama|Romance|War
# ...

# %%
# 나중에 쓸 수도 있으니 title을 빼놓자.
title = ratings['title']

# %%
# 고유한 유저, 영화를 찾아내는 코드
user_unique = ratings['user_id'].unique()
title_unique = ratings['title'].unique()

# 유저, 영화 indexing 하는 코드 idx는 index의 약자입니다.
user_to_idx = {v:k for k,v in enumerate(user_unique)}
title_to_idx = {v:k for k,v in enumerate(title_unique)}

# 이미 유저와 영화의 index가 존재하지만, (새롭게, 임의로) 유저와 영화의 index를 만들었다.

# %%
# 인덱싱이 잘 되었는지 확인해 봅니다. 
print(user_to_idx['SJ'])    # 6040명의 유저 중 마지막으로 추가된 유저이니 6039가 나와야 합니다. 
print(title_to_idx['Tarzan (1999)'])
# Out:
# 6039
# 16

# %%
# indexing을 통해 데이터 컬럼 내 값을 바꾸는 코드
# dictionary 자료형의 get 함수는 https://wikidocs.net/16 을 참고하세요.

# user_to_idx.get을 통해 user_id 컬럼의 모든 값을 인덱싱한 Series를 구해 봅시다. 
# 혹시 정상적으로 인덱싱되지 않은 row가 있다면 인덱스가 NaN이 될 테니 dropna()로 제거합니다. 
temp_user_data = ratings['user_id'].map(user_to_idx.get).dropna()
if len(temp_user_data) == len(ratings):   # 모든 row가 정상적으로 인덱싱되었다면
    print('user_id column indexing OK!!')
    ratings['user_id'] = temp_user_data   # data['user_id']을 인덱싱된 Series로 교체해 줍니다. 
else:
    print('user_id column indexing Fail!!')

# artist_to_idx을 통해 artist 컬럼도 동일한 방식으로 인덱싱해 줍니다. 
temp_artist_data = ratings['title'].map(title_to_idx.get).dropna()
if len(temp_artist_data) == len(ratings):
    print('artist column indexing OK!!')
    ratings['title'] = temp_artist_data
else:
    print('artist column indexing Fail!!')

ratings
# Out:
# user_id column indexing OK!!
# artist column indexing OK!!
#     user_id  movie_id  counts  title  \
# 0         0      1193       5      0
# 1         0       661       3      1
# 2         0       914       3      2
# 3         0      3408       4      3
# 4         0      2355       5      4
# ..      ...       ...     ...    ...
# 0      6039      2687       5     16
# 1      6039        48       5     25
# 2      6039      1907       5     34
# 3      6039      1566       5     32
# 4      6039         1       5     40
#
#                                             genre
# 0                                           Drama
# 1                    Animation|Children's|Musical
# 2                                 Musical|Romance
# 3                                           Drama
# 4                     Animation|Children's|Comedy
# ..                                            ...
# 0                            Animation|Children's
# ...

# %% [markdown]
# ## 2.4. CSR matrix를 직접 만들어 봅시다.

# %%
# 유저의 수는 6040명이고, 영화의 개수는 3628개이다.
# 따라서 rating matrix는 (6040, 3628)의 행렬이어야 한다. 그리고 정말로 6040x3628 sparse matrix라는 표현이 있다.
# 6040과 3628을 곱하면 21913120이 된다. 하지만 실제 nonzero entry의 개수는 836483개로, 상대적으로 매우 적다. (sparse)

num_user = ratings['user_id'].nunique()
num_title = ratings['title'].nunique()
print('num_user :',num_user)
print('num_title :',num_title)

csr_data = csr_matrix((ratings.counts, (ratings.user_id, ratings.title)), shape= (num_user, num_title))
csr_data
# Out:
# num_user : 6040
# num_title : 3628
# <6040x3628 sparse matrix of type '<class 'numpy.int64'>'
# 	with 836483 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## 2.5. als_model = AlternatingLeastSquares 모델을 직접 구성하여 훈련시켜 봅시다.

# %% [markdown]
# ## 2.6. 내가 선호하는 5가지 영화 중 하나와 그 외의 영화 하나를 골라 훈련된 모델이 예측한 나의 선호도를 파악해 보세요.

# %% [markdown]
# 2-5, 2-6의 문제를 다음과 같이 바꿔보자.
#  - 모델 학습시, 주요 변수는 `factors`와 `iterations`이다. 이것들이 default값(`factors=100`, `iterations=15`)일 때, 충분히 학습하지 못하는 것으로 보인다.
#  이 값들 중 `factor`를 변화시키면서 실험해본다.
#    - FACTORS = [300, 1000]
#  - 선호도를 계산하는 대상이 되는 영화들은 세 분류로 나뉘어야 할 것이다 : 내가 추가한 5가지 영화 / 내가 추가한 영화와 비슷한 장르의 영화 / 아예 다른 장르의 영화
#    - 내가 추가한 5가지 영화 (`A` ; animation)
#      - Tarzan (1999)
#      - Pocahontas (1995)
#      - Mulan (1998)
#      - Hercules (1997)
#      - Toy Story (1995)
#    - 내가 추가한 영화와 비슷한 장르의 영화 (`S` ; similar)
#      - Aladdin (1992)
#      - Toy Story 2 (1999)
#      - Little Mermaid, The (1989)
#      - Bug's Life, A (1998)
#      - Antz (1998)
#    - 아예 다른 장르의 영화 (`D` ; different)
#      - Matrix, The (1999)
#      - Fight Club (1999)
#      - Sixth Sense, The (1999)
#      - Shawshank Redemption, The (1994)
#      - Gone with the Wind (1939)

# %%
# implicit 라이브러리에서 권장하고 있는 부분입니다. 학습 내용과는 무관합니다.
os.environ['OPENBLAS_NUM_THREADS']='1'
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ['MKL_NUM_THREADS']='1'

# %%
# als 모델은 input으로 (item X user 꼴의 matrix를 받기 때문에 Transpose해줍니다.)
csr_data_transpose = csr_data.T
csr_data_transpose
# Out:
# <3628x6040 sparse matrix of type '<class 'numpy.int64'>'
# 	with 836483 stored elements in Compressed Sparse Column format>

# %% [markdown]
# ### 2.6.1. factors=300, iterations=15

# %%
# Implicit AlternatingLeastSquares 모델의 선언
als_model = AlternatingLeastSquares(factors=300, regularization=0.01, use_gpu=False, iterations=15, dtype=np.float32)

# %%
# 모델 훈련
als_model.fit(csr_data_transpose)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
sj = user_to_idx['SJ']
sj_vector = als_model.user_factors[sj]

# %%
A = ['Tarzan (1999)', 'Pocahontas (1995)', 'Mulan (1998)', 'Hercules (1997)', 'Toy Story (1995)']
S = ['Aladdin (1992)', 'Toy Story 2 (1999)', 'Little Mermaid, The (1989)', "Bug's Life, A (1998)", 'Antz (1998)']
D = ['Matrix, The (1999)', 'Fight Club (1999)','Sixth Sense, The (1999)','Shawshank Redemption, The (1994)','Gone with the Wind (1939)']

# %%
dotA = []
dotS = []
dotD = []
for a in A:
    a_index = title_to_idx[a]
    a_vector = als_model.item_factors[a_index]
    dotA.append(np.dot(sj_vector,a_vector))
for s in S:
    s_index = title_to_idx[s]
    s_vector = als_model.item_factors[s_index]
    dotS.append(np.dot(sj_vector,s_vector))
for d in D:
    d_index = title_to_idx[d]
    d_vector = als_model.item_factors[d_index]
    dotD.append(np.dot(sj_vector,d_vector))
print('trained ones :', dotA)
print('similar genre :', dotS)
print('different genre :', dotD)
# Out:
# trained ones : [0.7116681, 0.52581304, 0.6897246, 0.68950844, 0.8209026]
# similar genre : [0.34584934, 0.28981373, 0.15390542, 0.28683838, 0.25770333]
# different genre : [0.047267202, 0.007776186, 0.011807493, 0.01896262, 0.06339615]

# %% [markdown]
# ### 2.6.2. factors=1000, iterations=15

# %%
# Implicit AlternatingLeastSquares 모델의 선언
als_model = AlternatingLeastSquares(factors=1000, regularization=0.01, use_gpu=False, iterations=15, dtype=np.float32)

# %%
# 모델 훈련
als_model.fit(csr_data_transpose)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
sj = user_to_idx['SJ']
sj_vector = als_model.user_factors[sj]

# %%
A = ['Tarzan (1999)', 'Pocahontas (1995)', 'Mulan (1998)', 'Hercules (1997)', 'Toy Story (1995)']
S = ['Aladdin (1992)', 'Toy Story 2 (1999)', 'Little Mermaid, The (1989)', "Bug's Life, A (1998)", 'Antz (1998)']
D = ['Matrix, The (1999)', 'Fight Club (1999)','Sixth Sense, The (1999)','Shawshank Redemption, The (1994)','Gone with the Wind (1939)']

# %%
dotA = []
dotS = []
dotD = []
for a in A:
    a_index = title_to_idx[a]
    a_vector = als_model.item_factors[a_index]
    dotA.append(np.dot(sj_vector,a_vector))
for s in S:
    s_index = title_to_idx[s]
    s_vector = als_model.item_factors[s_index]
    dotS.append(np.dot(sj_vector,s_vector))
for d in D:
    d_index = title_to_idx[d]
    d_vector = als_model.item_factors[d_index]
    dotD.append(np.dot(sj_vector,d_vector))
print('trained ones :', dotA)
print('similar genre :', dotS)
print('different genre :', dotD)
# Out:
# trained ones : [0.9260762, 0.8082116, 0.91463965, 0.9078834, 0.98671424]
# similar genre : [0.08674208, 0.048096176, 0.06734663, 0.044747338, 0.06751871]
# different genre : [0.015523456, 0.016073603, 0.023309363, 0.029740112, 0.009226443]

# %% [markdown]
# ### 2.6.3. factors=300, iterations=50

# %%
# Implicit AlternatingLeastSquares 모델의 선언
als_model = AlternatingLeastSquares(factors=300, regularization=0.01, use_gpu=False, iterations=50, dtype=np.float32)

# %%
# 모델 훈련
als_model.fit(csr_data_transpose)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
sj = user_to_idx['SJ']
sj_vector = als_model.user_factors[sj]

# %%
A = ['Tarzan (1999)', 'Pocahontas (1995)', 'Mulan (1998)', 'Hercules (1997)', 'Toy Story (1995)']
S = ['Aladdin (1992)', 'Toy Story 2 (1999)', 'Little Mermaid, The (1989)', "Bug's Life, A (1998)", 'Antz (1998)']
D = ['Matrix, The (1999)', 'Fight Club (1999)','Sixth Sense, The (1999)','Shawshank Redemption, The (1994)','Gone with the Wind (1939)']

# %%
dotA = []
dotS = []
dotD = []
for a in A:
    a_index = title_to_idx[a]
    a_vector = als_model.item_factors[a_index]
    dotA.append(np.dot(sj_vector,a_vector))
for s in S:
    s_index = title_to_idx[s]
    s_vector = als_model.item_factors[s_index]
    dotS.append(np.dot(sj_vector,s_vector))
for d in D:
    d_index = title_to_idx[d]
    d_vector = als_model.item_factors[d_index]
    dotD.append(np.dot(sj_vector,d_vector))
print('trained ones :', dotA)
print('similar genre :', dotS)
print('different genre :', dotD)
# Out:
# trained ones : [0.69488955, 0.51960224, 0.71190244, 0.695903, 0.8229865]
# similar genre : [0.3562708, 0.3342172, 0.21024676, 0.25935614, 0.27491015]
# different genre : [0.106841676, 0.0043877955, 0.051648237, 0.05074554, 0.060307536]

# %% [markdown]
# ### 2.6.4. factors=1000, iterations=50

# %%
# Implicit AlternatingLeastSquares 모델의 선언
als_model = AlternatingLeastSquares(factors=1000, regularization=0.01, use_gpu=False, iterations=15, dtype=np.float32)

# %%
# 모델 훈련
als_model.fit(csr_data_transpose)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
sj = user_to_idx['SJ']
sj_vector = als_model.user_factors[sj]

# %%
A = ['Tarzan (1999)', 'Pocahontas (1995)', 'Mulan (1998)', 'Hercules (1997)', 'Toy Story (1995)']
S = ['Aladdin (1992)', 'Toy Story 2 (1999)', 'Little Mermaid, The (1989)', "Bug's Life, A (1998)", 'Antz (1998)']
D = ['Matrix, The (1999)', 'Fight Club (1999)','Sixth Sense, The (1999)','Shawshank Redemption, The (1994)','Gone with the Wind (1939)']

# %%
dotA = []
dotS = []
dotD = []
for a in A:
    a_index = title_to_idx[a]
    a_vector = als_model.item_factors[a_index]
    dotA.append(np.dot(sj_vector,a_vector))
for s in S:
    s_index = title_to_idx[s]
    s_vector = als_model.item_factors[s_index]
    dotS.append(np.dot(sj_vector,s_vector))
for d in D:
    d_index = title_to_idx[d]
    d_vector = als_model.item_factors[d_index]
    dotD.append(np.dot(sj_vector,d_vector))
print('trained ones :', dotA)
print('similar genre :', dotS)
print('different genre :', dotD)
# Out:
# trained ones : [0.9260762, 0.8082116, 0.91463965, 0.9078834, 0.98671424]
# similar genre : [0.08674208, 0.048096176, 0.06734663, 0.044747338, 0.06751871]
# different genre : [0.015523456, 0.016073603, 0.023309363, 0.029740112, 0.009226443]

# %% [markdown]
# ## 2.7. 내가 좋아하는 영화와 비슷한 영화를 추천받아 봅시다.

# %%
favorite_title = 'Tarzan (1999)'
title_id = title_to_idx[favorite_title]
similar_title = als_model.similar_items(title_id, N=15)
similar_title
# Out:
# [(16, 1.0000001),
#  (34, 0.62810737),
#  (32, 0.48752046),
#  (35, 0.43903536),
#  (329, 0.43369946),
#  (30, 0.38771498),
#  (1640, 0.36244482),
#  (25, 0.36219522),
#  (951, 0.36192113),
#  (330, 0.35830358),
#  (2138, 0.35705253),
#  (947, 0.35334104),
#  (1513, 0.34417507),
#  (1991, 0.34363064),
#  (1635, 0.34280288)]

# %%
#artist_to_idx 를 뒤집어, index로부터 artist 이름을 얻는 dict를 생성합니다. 
idx_to_title = {v:k for k,v in title_to_idx.items()}
[idx_to_title[i[0]] for i in similar_title]
# Out:
# ['Tarzan (1999)',
#  'Mulan (1998)',
#  'Hercules (1997)',
#  'Hunchback of Notre Dame, The (1996)',
#  'Anastasia (1997)',
#  'Antz (1998)',
#  'Road to El Dorado, The (2000)',
#  'Pocahontas (1995)',
#  'Rescuers Down Under, The (1990)',
#  'Lion King, The (1994)',
#  "Doug's 1st Movie (1999)",
#  'Swan Princess, The (1994)',
#  'Balto (1995)',
#  'Rugrats Movie, The (1998)',
#  'Dinosaur (2000)']

# %%
def get_similar_title(title_name: str):
    title_id = title_to_idx[title_name]
    similar_title = als_model.similar_items(title_id)
    similar_title = [idx_to_title[i[0]] for i in similar_title]
    return similar_title

print("슝=3")
# Out:
# 슝=3

# %%
get_similar_title('Tarzan (1999)')
# Out:
# ['Tarzan (1999)',
#  'Mulan (1998)',
#  'Hercules (1997)',
#  'Hunchback of Notre Dame, The (1996)',
#  'Anastasia (1997)',
#  'Antz (1998)',
#  'Road to El Dorado, The (2000)',
#  'Pocahontas (1995)',
#  'Rescuers Down Under, The (1990)',
#  'Lion King, The (1994)']

# %%
get_similar_title('Matrix, The (1999)')
# Out:
# ['Matrix, The (1999)',
#  'Terminator 2: Judgment Day (1991)',
#  'Total Recall (1990)',
#  'Fugitive, The (1993)',
#  'Face/Off (1997)',
#  'Fifth Element, The (1997)',
#  'Mifune (Mifunes sidste sang) (1999)',
#  'Surviving Picasso (1996)',
#  'If.... (1968)',
#  'Second Jungle Book: Mowgli & Baloo, The (1997)']

# %% [markdown]
# ## 2.8. 내가 가장 좋아할 만한 영화들을 추천받아 봅시다.

# %%
user = user_to_idx['SJ']
# recommend에서는 user*item CSR Matrix를 받습니다.
title_recommended = als_model.recommend(user, csr_data, N=20, filter_already_liked_items=True)
title_recommended
# Out:
# [(35, 0.46966568),
#  (330, 0.40478277),
#  (33, 0.35627085),
#  (329, 0.34606814),
#  (50, 0.33421725),
#  (10, 0.32190073),
#  (30, 0.27491015),
#  (4, 0.2593562),
#  (1, 0.23124444),
#  (191, 0.21024676),
#  (841, 0.20617107),
#  (851, 0.20544595),
#  (1556, 0.16982888),
#  (951, 0.16161978),
#  (1036, 0.15594375),
#  (1982, 0.15414448),
#  (513, 0.14772964),
#  (387, 0.1464528),
#  (1996, 0.14095598),
#  (120, 0.13481057)]

# %%
[idx_to_title[i[0]] for i in title_recommended]
# Out:
# ['Hunchback of Notre Dame, The (1996)',
#  'Lion King, The (1994)',
#  'Aladdin (1992)',
#  'Anastasia (1997)',
#  'Toy Story 2 (1999)',
#  'Beauty and the Beast (1991)',
#  'Antz (1998)',
#  "Bug's Life, A (1998)",
#  'James and the Giant Peach (1996)',
#  'Little Mermaid, The (1989)',
#  'Prince of Egypt, The (1998)',
#  'Iron Giant, The (1999)',
#  'Aladdin and the King of Thieves (1996)',
#  'Rescuers Down Under, The (1990)',
#  'Princess Mononoke, The (Mononoke Hime) (1997)',
#  'Space Jam (1996)',
#  'Jumanji (1995)',
#  'Batman: Mask of the Phantasm (1993)',
#  'George of the Jungle (1997)',
#  'Raiders of the Lost Ark (1981)']

# %%
Lion = title_to_idx['Lion King, The (1994)']
explain = als_model.explain(user, csr_data, itemid=Lion)

# %%
[(idx_to_title[i[0]], i[1]) for i in explain[1]]
# Out:
# [('Tarzan (1999)', 0.11205011027643885),
#  ('Mulan (1998)', 0.10701346856999253),
#  ('Toy Story (1995)', 0.06825021474303583),
#  ('Pocahontas (1995)', 0.05945071761067893),
#  ('Hercules (1997)', 0.0546041876706703)]

# %% [markdown]
# # 3. 결과 정리 및 회고

# %% [markdown]
# 1.
